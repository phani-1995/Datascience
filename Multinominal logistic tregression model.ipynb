# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv("D:\\projects\\Classifications model\\Multiple logistic regression model\\glass.csv")
data
# Out:
#       Id       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  \
# 0      1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
#      Type of glass
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 209              7
# 210              7
# 211              7
# 212              7
# 213              7
#
# [214 rows x 11 columns]

# %%
x = data.iloc[:,0:10]
y = data.iloc[:,-1]

# %%
y = Glass.iloc[:,-1]

# %%
clf = LogisticRegression(random_state=0,multi_class='multinomial',solver='newton-cg')
model = clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

# %%
#import the metrics class
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
print(cnf_matrix) #.... are incorrect predictions
#Accuracy
print("accuracy:"clf_matrix.accuracy_score(y_test,y_pred))
# Out:
#   File "<ipython-input-44-bcb5fa7d1cad>", line 6
#     print("accuracy:"clf_matrix.accuracy_score(y_test,y_pred))
#                               ^
# SyntaxError: invalid syntax

# %%
#create new observations
new_observation = [1.5159,13.02,3.58,1.51,73.12,0.69,7.96,0,0,0]
#predict class
y_pred = model.predict([new_observation])
#view predicted probabilities
probability = model.predict_proba([new_observation])

# %%
if y_pred == 1:
    lbl1 = 'building windows'
else:
    if y_pred == 2:
        lbl1 = 'building_windows_non_float_processed'
    else:
        if y_pred == 3:
            lbl1 = 'vehicle_windows_float_processed'
        else:
            if y_pred ==4:
                lbl1 = 'vehicle_windows_non_float_processed'
            else:
                if y_pred == 5:
                    lbl1 = 'containers'
                else:
                    if y_pred == 6:
                        lbl1 = 'tableware'
                    else:
                        if y_pred == 7:
                            lbl1 = 'headlamps'

# %%
'Predict the glass type :',lbl1
'Predicted probability of the glass type is :', probability
# Out:
# ('Predicted probability of the glass type is :',
#  array([[9.99999851e-001, 1.49026081e-007, 5.24947659e-070,
#          2.78946492e-054, 2.17524181e-118, 1.35168633e-144]]))

# %%
import seaborn as sns
corr = data.corr()
print('Glass values correlation')
sns.heatmap(corr, annot = True)
# Out:
# Glass values correlation

# %%
data.hist(bins=50, figsize=(15,10))
plt.show()
