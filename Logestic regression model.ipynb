# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
pima = pd.read_csv("D:\\projects\\Classifications model\\Linear Logistic model\\diabetes.csv", header= None)
pima
# Out:
#                0        1              2              3        4     5  \
# 0    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1              6      148             72             35        0  33.6
# 2              1       85             66             29        0  26.6
# 3              8      183             64              0        0  23.3
# 4              1       89             66             23       94  28.1
# ..           ...      ...            ...            ...      ...   ...
# 764           10      101             76             48      180  32.9
# 765            2      122             70             27        0  36.8
# 766            5      121             72             23      112  26.2
# 767            1      126             60              0        0  30.1
# 768            1       93             70             31        0  30.4
#
#                             6    7        8
# 0    DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
pima.head()
# Out:
#              0        1              2              3        4     5  \
# 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 1            6      148             72             35        0  33.6
# 2            1       85             66             29        0  26.6
# 3            8      183             64              0        0  23.3
# 4            1       89             66             23       94  28.1
#
#                           6    7        8
# 0  DiabetesPedigreeFunction  Age  Outcome
# 1                     0.627   50        1
# 2                     0.351   31        0
# 3                     0.672   32        1
# 4                     0.167   21        0

# %%
pima.describe()
# Out:
#           0    1    2    3    4    5      6    7    8
# count   769  769  769  769  769  769    769  769  769
# unique   18  137   48   52  187  249    518   53    3
# top       1  100   70    0    0   32  0.254   22    0
# freq    135   17   57  227  374   13      6   72  500

# %%
pima.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
