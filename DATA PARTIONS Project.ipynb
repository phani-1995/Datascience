# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading https://files.pythonhosted.org/packages/1e/7a/dbb3be0ce9bd5c8b7e3d87328e79063f8b263b2b1bfa4774cb1147bfcd3f/sklearn-0.0.tar.gz
# Requirement already satisfied: scikit-learn in c:\anacondainterpreter\lib\site-packages (from sklearn) (0.21.3)
# Requirement already satisfied: joblib>=0.11 in c:\anacondainterpreter\lib\site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied: scipy>=0.17.0 in c:\anacondainterpreter\lib\site-packages (from scikit-learn->sklearn) (1.3.1)
# Requirement already satisfied: numpy>=1.11.0 in c:\anacondainterpreter\lib\site-packages (from scikit-learn->sklearn) (1.16.5)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1321 sha256=c7bf0dd24aa1959991ae24642ed642cb07ec9571fc4546125f698a347e77fc19
#   Stored in directory: C:\Users\p#an!\AppData\Local\pip\Cache\wheels\76\03\bb\589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

# %%
df = pd.read_csv("D:\\projects\\Employee_Compensation.csv")
df
# Out:
#        Year Type  Year  Organization Group Code  \
# 0       Calendar  2028                        1
# 1       Calendar  2028                        7
# 2         Fiscal  2028                        1
# 3         Fiscal  2020                        3
# 4         Fiscal  2020                        2
# ...          ...   ...                      ...
# 880785    Fiscal  2013                        5
# 880786    Fiscal  2013                        6
# 880787    Fiscal  2013                        2
# 880788    Fiscal  2013                        1
# 880789    Fiscal  2013                        1
#
#                               Organization Group Department Code  \
# 0                              Public Protection             CRT
# 1                  General City Responsibilities          229259
# 2                              Public Protection             CRT
# 3       Human Welfare & Neighborhood Development             HSA
# 4        Public Works, Transportation & Commerce             AIR
# ...                                          ...             ...
# 880785                      Culture & Recreation             REC
# 880786          General Administration & Finance             ADM
# 880787   Public Works, Transportation & Commerce             DPW
# 880788                         Public Protection             SHF
# 880789                         Public Protection             POL
#
#                             Department Union Code  \
# 0                                  NaN        792
# 1                                  NaN        792
# 2                                  NaN        792
# 3                                  NaN        261
# 4                                  NaN        790
# ...                                ...        ...
# 880785    REC Recreation & Park Commsn        790
# 880786  ADM Gen Svcs Agency-City Admin         21
# 880787          DPW GSA - Public Works        216
# 880788                     SHF Sheriff        790
# 880789                      POL Police        911
#
#                                                   Union Job Family Code  \
# 0                        Utd Pub EmpL790 SEIU-Crt Clrks            0000
# 1                        Utd Pub EmpL790 SEIU-Crt Clrks            0000
# 2                        Utd Pub EmpL790 SEIU-Crt Clrks            0000
# 3                                   Laborers, Local 261            9900
# 4                                SEIU, Local 1021, Misc            9900
# ...                                                 ...             ...
# 880785                 SEIU - Miscellaneous, Local 1021            9900
# 880786  Prof & Tech Engineers - Miscellaneous, Local 21            6100
# 880787                             Teamsters, Local 853            7300
# 880788                 SEIU - Miscellaneous, Local 1021            8200
# 880789                     Police Officers' Association            Q000
#
#                             Job Family  ... Employee Identifier   Salaries  \
# 0                             Untitled  ...             8540990     674.28
# 1                             Untitled  ...             8540990     674.28
# 2                             Untitled  ...             8540990     674.28
# 3                  Public Service Aide  ...            10520146    5926.66
# 4                  Public Service Aide  ...            10970158    2781.75
# ...                                ...  ...                 ...        ...
# 880785             Public Service Aide  ...                4451    2526.75
# 880786  Health & Sanitation Inspection  ...               55049   56469.62
# 880787                Journeyman Trade  ...                2678   60489.33
# 880788       Protection & Apprehension  ...               25915     242.40
# 880789                 Police Services  ...                9751  102973.07
#
#         Overtime  Other Salaries  Total Salary  Retirement  Health and Dental  \
# 0           0.00            5.76        680.04      130.91               0.00
# 1           0.00            5.76        680.04      130.91               0.00
# 2           0.00            5.76        680.04      130.91               0.00
# 3           0.00          191.56       6118.22        0.00            2822.41
# 4           0.00            0.00       2781.75        0.00               0.00
# ...          ...             ...           ...         ...                ...
# 880785      0.00           22.56       2549.31        0.00            1483.28
# 880786      0.00            0.00      56469.62    10000.84            6499.37
# 880787    412.72         1640.91      62542.96    11313.92           11121.57
# 880788      0.00            0.00        242.40       44.14               0.00
# 880789   9466.78         8971.74     121411.59    18363.55           11201.56
#
#         Other Benefits  Total Benefits  Total Compensation
# 0                53.86          184.77              864.81
# 1                53.86          184.77              864.81
# 2                53.86          184.77              864.81
# 3               481.13         3303.54             9421.76
# 4               215.91          215.91             2997.66
# ...                ...             ...                 ...
# 880785          197.36         1680.64             4229.95
# 880786         4359.13        20859.34            77328.96
# 880787         5142.23        27577.72            90120.68
# 880788           32.73           76.87              319.27
# 880789         2063.09        31628.20           153039.79
#
# [880790 rows x 22 columns]

# %%
df.head()
df.shape
# Out:
# (880790, 22)

# %%
x=df.drop('Salaries',axis=1)
x
# Out:
#        Year Type  Year  Organization Group Code  \
# 0       Calendar  2028                        1
# 1       Calendar  2028                        7
# 2         Fiscal  2028                        1
# 3         Fiscal  2020                        3
# 4         Fiscal  2020                        2
# ...          ...   ...                      ...
# 880785    Fiscal  2013                        5
# 880786    Fiscal  2013                        6
# 880787    Fiscal  2013                        2
# 880788    Fiscal  2013                        1
# 880789    Fiscal  2013                        1
#
#                               Organization Group Department Code  \
# 0                              Public Protection             CRT
# 1                  General City Responsibilities          229259
# 2                              Public Protection             CRT
# 3       Human Welfare & Neighborhood Development             HSA
# 4        Public Works, Transportation & Commerce             AIR
# ...                                          ...             ...
# 880785                      Culture & Recreation             REC
# 880786          General Administration & Finance             ADM
# 880787   Public Works, Transportation & Commerce             DPW
# 880788                         Public Protection             SHF
# 880789                         Public Protection             POL
#
#                             Department Union Code  \
# 0                                  NaN        792
# 1                                  NaN        792
# 2                                  NaN        792
# 3                                  NaN        261
# 4                                  NaN        790
# ...                                ...        ...
# 880785    REC Recreation & Park Commsn        790
# 880786  ADM Gen Svcs Agency-City Admin         21
# 880787          DPW GSA - Public Works        216
# 880788                     SHF Sheriff        790
# 880789                      POL Police        911
#
#                                                   Union Job Family Code  \
# 0                        Utd Pub EmpL790 SEIU-Crt Clrks            0000
# 1                        Utd Pub EmpL790 SEIU-Crt Clrks            0000
# 2                        Utd Pub EmpL790 SEIU-Crt Clrks            0000
# 3                                   Laborers, Local 261            9900
# 4                                SEIU, Local 1021, Misc            9900
# ...                                                 ...             ...
# 880785                 SEIU - Miscellaneous, Local 1021            9900
# 880786  Prof & Tech Engineers - Miscellaneous, Local 21            6100
# 880787                             Teamsters, Local 853            7300
# 880788                 SEIU - Miscellaneous, Local 1021            8200
# 880789                     Police Officers' Association            Q000
#
#                             Job Family  ...                           Job  \
# 0                             Untitled  ...         Deputy Court Clerk II
# 1                             Untitled  ...         Deputy Court Clerk II
# 2                             Untitled  ...         Deputy Court Clerk II
# 3                  Public Service Aide  ...  Public Svc Aide-Public Works
# 4                  Public Service Aide  ...        Public Service Trainee
# ...                                ...  ...                           ...
# 880785             Public Service Aide  ...        Public Service Trainee
# 880786  Health & Sanitation Inspection  ...          Industrial Hygienist
# 880787                Journeyman Trade  ...                  Truck Driver
# 880788       Protection & Apprehension  ...      Fingerprint Technician 2
# 880789                 Police Services  ...              Police Officer 2
#
#        Employee Identifier  Overtime  Other Salaries  Total Salary  \
# 0                  8540990      0.00            5.76        680.04
# 1                  8540990      0.00            5.76        680.04
# 2                  8540990      0.00            5.76        680.04
# 3                 10520146      0.00          191.56       6118.22
# 4                 10970158      0.00            0.00       2781.75
# ...                    ...       ...             ...           ...
# 880785                4451      0.00           22.56       2549.31
# 880786               55049      0.00            0.00      56469.62
# 880787                2678    412.72         1640.91      62542.96
# 880788               25915      0.00            0.00        242.40
# 880789                9751   9466.78         8971.74     121411.59
#
#         Retirement  Health and Dental  Other Benefits  Total Benefits  \
# 0           130.91               0.00           53.86          184.77
# 1           130.91               0.00           53.86          184.77
# 2           130.91               0.00           53.86          184.77
# 3             0.00            2822.41          481.13         3303.54
# 4             0.00               0.00          215.91          215.91
# ...            ...                ...             ...             ...
# 880785        0.00            1483.28          197.36         1680.64
# 880786    10000.84            6499.37         4359.13        20859.34
# 880787    11313.92           11121.57         5142.23        27577.72
# 880788       44.14               0.00           32.73           76.87
# 880789    18363.55           11201.56         2063.09        31628.20
#
#         Total Compensation
# 0                   864.81
# 1                   864.81
# 2                   864.81
# 3                  9421.76
# 4                  2997.66
# ...                    ...
# 880785             4229.95
# 880786            77328.96
# 880787            90120.68
# 880788              319.27
# 880789           153039.79
#
# [880790 rows x 21 columns]

# %%
#The line test_size=0.2 suggests that the test data should be 10% of the dataset

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)
x_train.head()
# Out:
#        Year Type  Year  Organization Group Code  \
# 669097  Calendar  2015                        1
# 475101  Calendar  2017                        7
# 350366  Calendar  2017                        2
# 610757    Fiscal  2016                        2
# 451475  Calendar  2017                        2
#
#                              Organization Group     Department Code  \
# 669097                        Public Protection                 CRT
# 475101            General City Responsibilities  __NOT_APPLICABLE__
# 350366  Public Works, Transportation & Commerce                 PRT
# 610757  Public Works, Transportation & Commerce                 WTR
# 451475  Public Works, Transportation & Commerce                 MTA
#
#                   Department Union Code  \
# 669097    CRT Superior Court        197
# 475101                   NaN        790
# 350366              PRT Port         21
# 610757  WTR Water Enterprise        261
# 451475                   NaN        253
#
#                                                     Union Job Family Code  \
# 669097  Prof & Tech Engineers - Court Reporters, Local 21            SCRT
# 475101                             SEIU, Local 1021, Misc            1800
# 350366    Prof & Tech Engineers - Miscellaneous, Local 21            1600
# 610757                                Laborers, Local 261            7500
# 451475                       TWU, Local 250-A, TransitOpr            9100
#
#                            Job Family  ...                     Job  \
# 669097              SF Superior Court  ...          Court Reporter
# 475101  Budget, Admn & Stats Analysis  ...  Administrative Analyst
# 350366  Payroll, Billing & Accounting  ...       Accountant Intern
# 610757   Semi-Skilled & General Labor  ...         General Laborer
# 451475                 Street Transit  ...        Transit Operator
#
#        Employee Identifier  Overtime  Other Salaries  Total Salary  \
# 669097               17518      0.00         5903.04     113231.04
# 475101             8504844      0.00            0.00          0.00
# 350366               39486      0.00            0.00       4736.00
# 610757               51723   1010.35          271.01      63833.98
# 451475             8588862      0.00            0.00          0.00
#
#         Retirement  Health and Dental  Other Benefits  Total Benefits  \
# 669097    23059.13           12424.50         9375.84        44859.47
# 475101        0.00               0.00            0.00            0.00
# 350366      863.38            1080.99          369.64         2314.01
# 610757    11691.51           12490.09         5293.13        29474.73
# 451475        0.00           13792.38            0.00            0.00
#
#         Total Compensation
# 669097           158090.51
# 475101                0.00
# 350366             7050.01
# 610757            93308.71
# 451475                0.00
#
# [5 rows x 21 columns]

# %%
x_train.shape
# Out:
# (792711, 21)

# %%
x_test.head()
# Out:
#        Year Type  Year  Organization Group Code  \
# 631894    Fiscal  2016                        2
# 615811    Fiscal  2016                        5
# 767129    Fiscal  2014                        1
# 127946  Calendar  2019                        2
# 170799    Fiscal  2019                        2
#
#                              Organization Group Department Code  \
# 631894  Public Works, Transportation & Commerce             PRT
# 615811                     Culture & Recreation             LIB
# 767129                        Public Protection             SHF
# 127946  Public Works, Transportation & Commerce             AIR
# 170799  Public Works, Transportation & Commerce             MTA
#
#                 Department Union Code  \
# 631894            PRT Port         21
# 615811  LIB Public Library        790
# 767129         SHF Sheriff        498
# 127946                 NaN         39
# 170799                 NaN        200
#
#                                                   Union Job Family Code  \
# 631894  Prof & Tech Engineers - Miscellaneous, Local 21            5300
# 615811                 SEIU - Miscellaneous, Local 1021            3600
# 767129                     Deputy Sheriffs' Association            8300
# 127946                   Stationary Engineers, Local 39            7300
# 170799                                   TWU, Local 200            9100
#
#                           Job Family  ...                             Job  \
# 631894  Sub-Professional Engineering  ...  Stdntdsgntrain3, Arch/Eng/Plng
# 615811                       Library  ...                     Librarian 2
# 767129        Correction & Detention  ...                  Deputy Sheriff
# 127946              Journeyman Trade  ...             Stationary Engineer
# 170799                Street Transit  ...              Transit Supervisor
#
#        Employee Identifier  Overtime  Other Salaries  Total Salary  \
# 631894                9496      0.00            0.00      20082.41
# 615811               32853      0.00          628.80      96624.51
# 767129               45276  53167.40        20247.89     165291.56
# 127946             8495787   3715.95            0.00     109034.22
# 170799             8516340  16384.01         8268.75     126977.76
#
#         Retirement  Health and Dental  Other Benefits  Total Benefits  \
# 631894        0.00            4314.43         1529.13         5843.56
# 615811    17981.78           13067.98         8022.22        39071.98
# 767129    20756.37           12343.56         2743.44        35843.37
# 127946    20131.85           22562.30         8293.46        58576.57
# 170799    21092.20           15075.63        10051.13        46218.96
#
#         Total Compensation
# 631894            25925.97
# 615811           135696.49
# 767129           201134.93
# 127946           167610.79
# 170799           173196.72
#
# [5 rows x 21 columns]

# %%
x_test.shape
# Out:
# (88079, 21)

# %%
###############################################################
###############################################################
######Let’s take another example. We’ll use the IRIS dataset this time.#####
#########################################################################

iris= load_iris()
x,y=iris.data,iris.target
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size = 0.5,test_size=0.5,random_state=123)
y_test
# Out:
# array([1, 2, 2, 1, 0, 2, 1, 0, 0, 1, 2, 0, 1, 2, 2, 2, 0, 0, 1, 0, 0, 2,
#        0, 2, 0, 0, 0, 2, 2, 0, 2, 2, 0, 0, 1, 1, 2, 0, 0, 1, 1, 0, 2, 2,
#        2, 2, 2, 1, 0, 0, 2, 0, 0, 1, 1, 1, 1, 2, 1, 2, 0, 2, 1, 0, 0, 2,
#        1, 2, 2, 0, 1, 1, 2, 0, 2])

# %%
y_train
# Out:
# array([1, 1, 0, 2, 2, 0, 0, 1, 1, 2, 0, 0, 1, 0, 1, 2, 0, 2, 0, 0, 1, 0,
#        0, 1, 2, 1, 1, 1, 0, 0, 1, 2, 0, 0, 1, 1, 1, 2, 1, 1, 1, 2, 0, 0,
#        1, 2, 2, 2, 2, 0, 1, 0, 1, 1, 0, 1, 2, 1, 2, 2, 0, 1, 0, 2, 2, 1,
#        1, 2, 2, 1, 0, 1, 1, 2, 2])

# %%
from sklearn.linear_model import LinearRegression as lm
model=lm().fit(x_train,y_train)
predictions=model.predict(x_test)
import matplotlib.pyplot as plt
plt.scatter(y_test,predictions)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.show()
